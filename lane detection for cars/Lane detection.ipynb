# %%
# program to find out edges upto canny function


import cv2
import numpy as np

def canny(image):
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # to reduce noise
    blur = cv2.GaussianBlur(gray,(5,5),0)

    # used for edge detection : identifying sharp changes in intensity in adjacent pixels
    canny = cv2.Canny(blur,50,150)
    
    return canny


# reading image
image = cv2.imread("test_image.jpg")
lane_image = np.copy(image)

canny = canny(lane_image)

#showing image
cv2.imshow("Image",canny)

# displaying this image infinitely untill a key is pressed
cv2.waitKey(0)

# cloas all the windows when key is pressed
cv2.destroyAllWindows()

# %% [raw]
# Gradient: Measure  of change in brightness over adjacent pixels
# Strong Gradient : 0 to 255
# Small Gradient : 0 to 15
#
#
# Why convert an image to grayscale before using canny on it?
# -> well an image has pixels and each pixel in the image is a combination of 3 intensity values(3 channels of colors)
# whereas a grayscale image has just 1st channel(processing 1 channel image is way faster than processing a 3 channel image)
#
# we refer edge in am image to a sharp change to an intensity or a sharp change in color between adjacent pixels in the image. The change in brightness over a series of pixels is the gradients, a strong gradient indicates a steep change whereas a smallgradient indicates a shallow change.
#
# Now a pixel cam be represented with a matrix that depicts intensities, similarly an image can be represented in the form of multuple matrices. Thus, a function of pixels intensities in all directions x & y can be formed
#
# WHat canny is gonna do is derivative(f(x,y)) => measures change in intensity in all directions , x & y, A small derivative is small change in intensities and a big derivative is strong change in intensities.
#
# Therefore, a canny function will find out derivatives of all the adjacent intensities of a blurred image and is going to trace out strongest gradients.
#
# cv2.Canny(image, low_threshold,high_threshold)
#
# the threshold means that the gradient must be between that specific range to be accepted as an edge.
# Small changes in brightness won't be accpted and will be considered as black in color.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def canny(image):
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # to reduce noise
    blur = cv2.GaussianBlur(gray,(5,5),0)

    # used for edge detection : identifying sharp changes in intensity in adjacent pixels
    canny = cv2.Canny(blur,50,150)
    
    return canny


# reading image
image = cv2.imread("test_image.jpg")
lane_image = np.copy(image)

canny = canny(lane_image)

#showing image
plt.imshow(canny)
plt.show()

# displaying this image infinitely untill a key is pressed
cv2.waitKey(0)

# cloas all the windows when key is pressed
cv2.destroyAllWindows()

# %% [markdown]
# # Complete code

# %%
import cv2
import numpy as np

def make_coordinates(image, line_parameters):
    slope, intercept = line_parameters
    print(image.shape)
    y1 = image.shape[0]
    y2 = int(y1*(3/5))
    x1 = int((y1 - intercept)/slope)
    x2 = int((y2 - intercept)/slope)
    return np.array([x1, y1, x2, y2])


def average_slope_intercept(image,lines):
    left_fit = []
    right_fit = []
    for line in lines:
        x1,y1,x2,y2 = line.reshape(4)
        parameters = np.polyfit((x1,x2),(y1, y2), 1)
        slope = parameters[0]
        intercept = parameters[1]
        if slope<0:
            left_fit.append((slope, intercept))
        else:
            right_fit.append((slope,intercept))
            
    left_fit_average = np.average(left_fit, axis=0)
    right_fit_average = np.average(right_fit, axis = 0)
    left_line = make_coordinates(image, left_fit_average)
    right_line = make_coordinates(image, right_fit_average)
    return np.array([left_line,right_line])



def canny(image):
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # to reduce noise
    blur = cv2.GaussianBlur(gray,(5,5),0)

    # used for edge detection : identifying sharp changes in intensity in adjacent pixels
    canny = cv2.Canny(blur,50,150)
    
    return canny

def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for x1,y1,x2,y2 in lines:
            cv2.line(line_image, (x1,y1), (x2,y2), (255,0,0), 10)
    return line_image


def region_of_interest(image):
    height = image.shape[0]
    polygons = np.array([
        [(200, height),(1100,height),(550,250)]
    ])
    mask = np.zeros_like(image)
    cv2.fillPoly(mask, polygons, 255)
    masked_image = cv2.bitwise_and(image,mask)
    return masked_image


# reading image
# image = cv2.imread("test_image.jpg")
# lane_image = np.copy(image)

# canny_image = canny(lane_image)

# cropped_image = region_of_interest(canny_image)

# lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]),minLineLength=40,maxLineGap=5)

# averaged_lines = average_slope_intercept(lane_image, lines)

# line_image = display_lines(lane_image,averaged_lines)

# combo_image = cv2.addWeighted(lane_image, 0.8, line_image, 1, 1 )

# #showing image
# cv2.imshow("Canny Image", combo_image)

# # displaying this image infinitely untill a key is pressed
# cv2.waitKey(0)

# # cloas all the windows when key is pressed
# cv2.destroyAllWindows()



cap = cv2.VideoCapture("test2.mp4")
while(cap.isOpened()):
    _, frame = cap.read()
    canny_image = canny(frame)

    cropped_image = region_of_interest(canny_image)

    lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]),minLineLength=40,maxLineGap=5)

    averaged_lines = average_slope_intercept(frame, lines)

    line_image = display_lines(frame,averaged_lines)

    combo_image = cv2.addWeighted(frame, 0.8, line_image, 1, 1 )

    #showing image
    cv2.imshow("Canny Image", combo_image)

    # displaying this image infinitely untill a key is pressed
    cv2.waitKey(1)

    # cloas all the windows when key is pressed
#     cv2.destroyAllWindows()
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# ...
